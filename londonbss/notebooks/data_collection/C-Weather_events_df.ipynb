# %% [markdown]
# # CREATE FULL WEATHER AND EVENTS DF

# %%
import requests
import pandas as pd
import dateutil.parser

# %% [markdown]
# ## 1. Getting daily sunrise and sunset times from the Open Meteo API

# %% [markdown]
# ### 1.1 Getting the data from the API

# %%
start_date = "2014-01-01"
end_date = "2023-08-20"
url = 'https://archive-api.open-meteo.com/v1/archive'

# %%
params_daily_dict ={
        "latitude":"51.5085", #London latitude - should remain hardcoded
        "longitude":"-0.1780971", #London longitude -should remain hardcoded
        "start_date":start_date, #could be defined in .env and used in the other files
        "end_date":end_date, #could be defined in .env and used in the other files
        "timezone":"Europe/London", #Europe/London - specific to this api
        "daily":"sunrise,sunset" # specific to this api
}

daily_weather_response = requests.get(
        url,
        params=params_daily_dict).json()

# %%
sun_df =pd.DataFrame()
sun_df["sunrise"] = daily_weather_response["daily"]["sunrise"]
sun_df["sunset"] = daily_weather_response["daily"]["sunset"]
sun_df.head()
# Out:
#             sunrise            sunset
# 0  2014-01-01T09:06  2014-01-01T17:02
# 1  2014-01-02T09:06  2014-01-02T17:03
# 2  2014-01-03T09:06  2014-01-03T17:04
# 3  2014-01-04T09:05  2014-01-04T17:05
# 4  2014-01-05T09:05  2014-01-05T17:06

# %% [markdown]
# ### 1.2 Daytime/nightime encoding

# %%
def date_parser(time):
    date_parser = dateutil.parser.isoparse(time)
    return date_parser

# %%
sun_df["sunrise_datetime"] = sun_df.apply(lambda x: date_parser(x["sunrise"]), axis = 1)

# %%
sun_df["sunset_datetime"] = sun_df.apply(lambda x: date_parser(x["sunset"]), axis = 1)

# %%
sun_df['date'] = sun_df['sunrise_datetime'].dt.date

# %%
sun_df.head()
# Out:
#             sunrise            sunset    sunrise_datetime     sunset_datetime  \
# 0  2014-01-01T09:06  2014-01-01T17:02 2014-01-01 09:06:00 2014-01-01 17:02:00
# 1  2014-01-02T09:06  2014-01-02T17:03 2014-01-02 09:06:00 2014-01-02 17:03:00
# 2  2014-01-03T09:06  2014-01-03T17:04 2014-01-03 09:06:00 2014-01-03 17:04:00
# 3  2014-01-04T09:05  2014-01-04T17:05 2014-01-04 09:05:00 2014-01-04 17:05:00
# 4  2014-01-05T09:05  2014-01-05T17:06 2014-01-05 09:05:00 2014-01-05 17:06:00
#
#          date
# 0  2014-01-01
# 1  2014-01-02
# 2  2014-01-03
# 3  2014-01-04
# 4  2014-01-05

# %%
def daytime_encoding(timestamp, sunrise_datetime, sunset_datetime):
    if timestamp < sunrise_datetime:
        daytime_encoding = "nighttime"
    elif timestamp >= sunrise_datetime and timestamp < sunset_datetime:
        daytime_encoding = "daytime"
    else:
        daytime_encoding = "nighttime"
    return daytime_encoding

# %% [markdown]
# ## 2. Getting hourly weather data from the Open Meteo API

# %% [markdown]
# ### 2.1 API data

# %%
params_hourly_dict ={
        "latitude":"51.5085", #London latitude - should remain hardcoded
        "longitude":"-0.1780971", #London longitude -should remain hardcoded
        "start_date":start_date, #could be defined in .env and used in the other files
        "end_date":end_date, #could be defined in .env and used in the other files
        "timezone":"Europe/London", #Europe/London - specific to this api
        "hourly":"temperature_2m,precipitation,rain,snowfall,cloudcover,windspeed_10m,winddirection_10m" # specific to this api
}

hourly_weather_response = requests.get(
    url,
    params=params_hourly_dict).json()

# %%
timestamp_api = hourly_weather_response["hourly"]["time"]
temperature_api = hourly_weather_response["hourly"]["temperature_2m"]
precipitation_api = hourly_weather_response["hourly"]["precipitation"]
rain_api = hourly_weather_response["hourly"]["rain"]
snow_api = hourly_weather_response["hourly"]["snowfall"]
cloudcover_api = hourly_weather_response["hourly"]["cloudcover"]
windspeed_api = hourly_weather_response["hourly"]["windspeed_10m"]
winddirection_api = hourly_weather_response["hourly"]["winddirection_10m"]

# %% [markdown]
# ### 2.2 Put the data into a df

# %%
weather_data = pd.DataFrame()
weather_data["timestamp"] = timestamp_api
weather_data["temperature"] = temperature_api
weather_data["precipitation"] = precipitation_api
weather_data["rainfall"] = rain_api
weather_data["snowfall"] = snow_api
weather_data["cloudcover"] = cloudcover_api
weather_data["wind_speed"] = windspeed_api
weather_data["wind_direction"]= winddirection_api

# %%
weather_data
# Out:
#               timestamp  temperature  precipitation  rainfall  snowfall  \
# 0      2014-01-01T00:00          6.2            0.0       0.0       0.0
# 1      2014-01-01T01:00          6.4            0.0       0.0       0.0
# 2      2014-01-01T02:00          6.5            0.0       0.0       0.0
# 3      2014-01-01T03:00          6.5            0.0       0.0       0.0
# 4      2014-01-01T04:00          6.4            0.0       0.0       0.0
# ...                 ...          ...            ...       ...       ...
# 84451  2023-08-20T19:00         21.4            0.0       0.0       0.0
# 84452  2023-08-20T20:00         20.1            0.0       0.0       0.0
# 84453  2023-08-20T21:00         18.6            0.0       0.0       0.0
# 84454  2023-08-20T22:00         17.8            0.0       0.0       0.0
# 84455  2023-08-20T23:00         16.8            0.0       0.0       0.0
#
#        cloudcover  wind_speed  wind_direction
# 0              87        22.3             194
# 1             100        24.6             201
# 2              63        25.0             205
# 3              40        24.5             208
# 4              84        23.0             207
# ...           ...         ...             ...
# 84451          33        12.0             226
# 84452          33        10.9             224
# 84453          27        10.7             222
# 84454          19        10.4             226
# 84455          14        10.7             228
#
# [84456 rows x 8 columns]

# %% [markdown]
# ### 2.3 Timestamp recoding

# %%
weather_data["timestamp"] = weather_data.apply(lambda x: date_parser(x["timestamp"]), axis = 1)

# %%
weather_data.head()
# Out:
#             timestamp  temperature  precipitation  rainfall  snowfall  \
# 0 2014-01-01 00:00:00          6.2            0.0       0.0       0.0
# 1 2014-01-01 01:00:00          6.4            0.0       0.0       0.0
# 2 2014-01-01 02:00:00          6.5            0.0       0.0       0.0
# 3 2014-01-01 03:00:00          6.5            0.0       0.0       0.0
# 4 2014-01-01 04:00:00          6.4            0.0       0.0       0.0
#
#    cloudcover  wind_speed  wind_direction
# 0          87        22.3             194
# 1         100        24.6             201
# 2          63        25.0             205
# 3          40        24.5             208
# 4          84        23.0             207

# %% [markdown]
# ### 2.4 Add the daytime & night time encoding to the full df

# %%
weather_data['date'] = weather_data['timestamp'].dt.date

# %%
weather_data
# Out:
#                 timestamp  temperature  precipitation  rainfall  snowfall  \
# 0     2014-01-01 00:00:00          6.2            0.0       0.0       0.0
# 1     2014-01-01 01:00:00          6.4            0.0       0.0       0.0
# 2     2014-01-01 02:00:00          6.5            0.0       0.0       0.0
# 3     2014-01-01 03:00:00          6.5            0.0       0.0       0.0
# 4     2014-01-01 04:00:00          6.4            0.0       0.0       0.0
# ...                   ...          ...            ...       ...       ...
# 84451 2023-08-20 19:00:00         21.4            0.0       0.0       0.0
# 84452 2023-08-20 20:00:00         20.1            0.0       0.0       0.0
# 84453 2023-08-20 21:00:00         18.6            0.0       0.0       0.0
# 84454 2023-08-20 22:00:00         17.8            0.0       0.0       0.0
# 84455 2023-08-20 23:00:00         16.8            0.0       0.0       0.0
#
#        cloudcover  wind_speed  wind_direction        date
# 0              87        22.3             194  2014-01-01
# 1             100        24.6             201  2014-01-01
# 2              63        25.0             205  2014-01-01
# 3              40        24.5             208  2014-01-01
# 4              84        23.0             207  2014-01-01
# ...           ...         ...             ...         ...
# 84451          33        12.0             226  2023-08-20
# 84452          33        10.9             224  2023-08-20
# 84453          27        10.7             222  2023-08-20
# 84454          19        10.4             226  2023-08-20
# 84455          14        10.7             228  2023-08-20
#
# [84456 rows x 9 columns]

# %%
weather_data = weather_data.merge(sun_df)

# %%
weather_data
# Out:
#                 timestamp  temperature  precipitation  rainfall  snowfall  \
# 0     2014-01-01 00:00:00          6.2            0.0       0.0       0.0
# 1     2014-01-01 01:00:00          6.4            0.0       0.0       0.0
# 2     2014-01-01 02:00:00          6.5            0.0       0.0       0.0
# 3     2014-01-01 03:00:00          6.5            0.0       0.0       0.0
# 4     2014-01-01 04:00:00          6.4            0.0       0.0       0.0
# ...                   ...          ...            ...       ...       ...
# 84451 2023-08-20 19:00:00         21.4            0.0       0.0       0.0
# 84452 2023-08-20 20:00:00         20.1            0.0       0.0       0.0
# 84453 2023-08-20 21:00:00         18.6            0.0       0.0       0.0
# 84454 2023-08-20 22:00:00         17.8            0.0       0.0       0.0
# 84455 2023-08-20 23:00:00         16.8            0.0       0.0       0.0
#
#        cloudcover  wind_speed  wind_direction        date           sunrise  \
# 0              87        22.3             194  2014-01-01  2014-01-01T09:06
# 1             100        24.6             201  2014-01-01  2014-01-01T09:06
# 2              63        25.0             205  2014-01-01  2014-01-01T09:06
# 3              40        24.5             208  2014-01-01  2014-01-01T09:06
# 4              84        23.0             207  2014-01-01  2014-01-01T09:06
# ...           ...         ...             ...         ...               ...
# 84451          33        12.0             226  2023-08-20  2023-08-20T05:54
# 84452          33        10.9             224  2023-08-20  2023-08-20T05:54
# 84453          27        10.7             222  2023-08-20  2023-08-20T05:54
# 84454          19        10.4             226  2023-08-20  2023-08-20T05:54
# 84455          14        10.7             228  2023-08-20  2023-08-20T05:54
#
#                  sunset    sunrise_datetime     sunset_datetime
# 0      2014-01-01T17:02 2014-01-01 09:06:00 2014-01-01 17:02:00
# 1      2014-01-01T17:02 2014-01-01 09:06:00 2014-01-01 17:02:00
# 2      2014-01-01T17:02 2014-01-01 09:06:00 2014-01-01 17:02:00
# 3      2014-01-01T17:02 2014-01-01 09:06:00 2014-01-01 17:02:00
# 4      2014-01-01T17:02 2014-01-01 09:06:00 2014-01-01 17:02:00
# ...                 ...                 ...                 ...
# 84451  2023-08-20T20:14 2023-08-20 05:54:00 2023-08-20 20:14:00
# 84452  2023-08-20T20:14 2023-08-20 05:54:00 2023-08-20 20:14:00
# 84453  2023-08-20T20:14 2023-08-20 05:54:00 2023-08-20 20:14:00
# 84454  2023-08-20T20:14 2023-08-20 05:54:00 2023-08-20 20:14:00
# 84455  2023-08-20T20:14 2023-08-20 05:54:00 2023-08-20 20:14:00
#
# [84456 rows x 13 columns]

# %%
weather_data["encoding"] = weather_data.apply(lambda x: daytime_encoding(x["timestamp"], x["sunrise_datetime"], x["sunset_datetime"]), axis = 1)

# %%
weather_data.head(20)
# Out:
#              timestamp  temperature  precipitation  rainfall  snowfall  \
# 0  2014-01-01 00:00:00          6.2            0.0       0.0       0.0
# 1  2014-01-01 01:00:00          6.4            0.0       0.0       0.0
# 2  2014-01-01 02:00:00          6.5            0.0       0.0       0.0
# 3  2014-01-01 03:00:00          6.5            0.0       0.0       0.0
# 4  2014-01-01 04:00:00          6.4            0.0       0.0       0.0
# 5  2014-01-01 05:00:00          6.2            0.0       0.0       0.0
# 6  2014-01-01 06:00:00          6.1            0.0       0.0       0.0
# 7  2014-01-01 07:00:00          6.4            0.0       0.0       0.0
# 8  2014-01-01 08:00:00          7.2            0.0       0.0       0.0
# 9  2014-01-01 09:00:00          7.3            0.0       0.0       0.0
# 10 2014-01-01 10:00:00          7.6            0.0       0.0       0.0
# 11 2014-01-01 11:00:00          7.8            0.5       0.5       0.0
# 12 2014-01-01 12:00:00          7.7            1.4       1.4       0.0
# 13 2014-01-01 13:00:00          7.8            1.9       1.9       0.0
# 14 2014-01-01 14:00:00          8.2            2.0       2.0       0.0
# 15 2014-01-01 15:00:00          8.8            1.1       1.1       0.0
# 16 2014-01-01 16:00:00          9.3            0.5       0.5       0.0
# 17 2014-01-01 17:00:00          9.6            1.0       1.0       0.0
# 18 2014-01-01 18:00:00          9.8            1.1       1.1       0.0
# 19 2014-01-01 19:00:00          9.9            0.4       0.4       0.0
#
#     cloudcover  wind_speed  wind_direction        date           sunrise  \
# 0           87        22.3             194  2014-01-01  2014-01-01T09:06
# 1          100        24.6             201  2014-01-01  2014-01-01T09:06
# 2           63        25.0             205  2014-01-01  2014-01-01T09:06
# 3           40        24.5             208  2014-01-01  2014-01-01T09:06
# 4           84        23.0             207  2014-01-01  2014-01-01T09:06
# 5           73        22.6             205  2014-01-01  2014-01-01T09:06
# 6           79        21.8             202  2014-01-01  2014-01-01T09:06
# 7           71        21.9             197  2014-01-01  2014-01-01T09:06
# 8          100        23.2             192  2014-01-01  2014-01-01T09:06
# 9          100        26.0             185  2014-01-01  2014-01-01T09:06
# 10         100        28.5             178  2014-01-01  2014-01-01T09:06
# 11         100        31.6             172  2014-01-01  2014-01-01T09:06
# 12         100        35.1             170  2014-01-01  2014-01-01T09:06
# 13         100        37.4             164  2014-01-01  2014-01-01T09:06
# 14         100        38.5             169  2014-01-01  2014-01-01T09:06
# 15         100        37.1             181  2014-01-01  2014-01-01T09:06
# 16         100        40.0             188  2014-01-01  2014-01-01T09:06
# 17         100        38.3             185  2014-01-01  2014-01-01T09:06
# 18         100        35.3             182  2014-01-01  2014-01-01T09:06
# 19         100        33.3             191  2014-01-01  2014-01-01T09:06
#
#               sunset    sunrise_datetime     sunset_datetime   encoding
# 0   2014-01-01T17:02 2014-01-01 09:06:00 2014-01-01 17:02:00  nighttime
# 1   2014-01-01T17:02 2014-01-01 09:06:00 2014-01-01 17:02:00  nighttime
# 2   2014-01-01T17:02 2014-01-01 09:06:00 2014-01-01 17:02:00  nighttime
# 3   2014-01-01T17:02 2014-01-01 09:06:00 2014-01-01 17:02:00  nighttime
# 4   2014-01-01T17:02 2014-01-01 09:06:00 2014-01-01 17:02:00  nighttime
# 5   2014-01-01T17:02 2014-01-01 09:06:00 2014-01-01 17:02:00  nighttime
# 6   2014-01-01T17:02 2014-01-01 09:06:00 2014-01-01 17:02:00  nighttime
# 7   2014-01-01T17:02 2014-01-01 09:06:00 2014-01-01 17:02:00  nighttime
# 8   2014-01-01T17:02 2014-01-01 09:06:00 2014-01-01 17:02:00  nighttime
# 9   2014-01-01T17:02 2014-01-01 09:06:00 2014-01-01 17:02:00  nighttime
# 10  2014-01-01T17:02 2014-01-01 09:06:00 2014-01-01 17:02:00    daytime
# 11  2014-01-01T17:02 2014-01-01 09:06:00 2014-01-01 17:02:00    daytime
# 12  2014-01-01T17:02 2014-01-01 09:06:00 2014-01-01 17:02:00    daytime
# 13  2014-01-01T17:02 2014-01-01 09:06:00 2014-01-01 17:02:00    daytime
# 14  2014-01-01T17:02 2014-01-01 09:06:00 2014-01-01 17:02:00    daytime
# 15  2014-01-01T17:02 2014-01-01 09:06:00 2014-01-01 17:02:00    daytime
# 16  2014-01-01T17:02 2014-01-01 09:06:00 2014-01-01 17:02:00    daytime
# 17  2014-01-01T17:02 2014-01-01 09:06:00 2014-01-01 17:02:00    daytime
# 18  2014-01-01T17:02 2014-01-01 09:06:00 2014-01-01 17:02:00  nighttime
# 19  2014-01-01T17:02 2014-01-01 09:06:00 2014-01-01 17:02:00  nighttime

# %%
weather_data_final = weather_data.drop(columns={"sunrise", "sunset"}, axis = 1)

# %%
weather_data_final
# Out:
#                 timestamp  temperature  precipitation  rainfall  snowfall  \
# 0     2014-01-01 00:00:00          6.2            0.0       0.0       0.0
# 1     2014-01-01 01:00:00          6.4            0.0       0.0       0.0
# 2     2014-01-01 02:00:00          6.5            0.0       0.0       0.0
# 3     2014-01-01 03:00:00          6.5            0.0       0.0       0.0
# 4     2014-01-01 04:00:00          6.4            0.0       0.0       0.0
# ...                   ...          ...            ...       ...       ...
# 84451 2023-08-20 19:00:00         21.4            0.0       0.0       0.0
# 84452 2023-08-20 20:00:00         20.1            0.0       0.0       0.0
# 84453 2023-08-20 21:00:00         18.6            0.0       0.0       0.0
# 84454 2023-08-20 22:00:00         17.8            0.0       0.0       0.0
# 84455 2023-08-20 23:00:00         16.8            0.0       0.0       0.0
#
#        cloudcover  wind_speed  wind_direction        date    sunrise_datetime  \
# 0              87        22.3             194  2014-01-01 2014-01-01 09:06:00
# 1             100        24.6             201  2014-01-01 2014-01-01 09:06:00
# 2              63        25.0             205  2014-01-01 2014-01-01 09:06:00
# 3              40        24.5             208  2014-01-01 2014-01-01 09:06:00
# 4              84        23.0             207  2014-01-01 2014-01-01 09:06:00
# ...           ...         ...             ...         ...                 ...
# 84451          33        12.0             226  2023-08-20 2023-08-20 05:54:00
# 84452          33        10.9             224  2023-08-20 2023-08-20 05:54:00
# 84453          27        10.7             222  2023-08-20 2023-08-20 05:54:00
# 84454          19        10.4             226  2023-08-20 2023-08-20 05:54:00
# 84455          14        10.7             228  2023-08-20 2023-08-20 05:54:00
#
#           sunset_datetime   encoding
# 0     2014-01-01 17:02:00  nighttime
# 1     2014-01-01 17:02:00  nighttime
# 2     2014-01-01 17:02:00  nighttime
# 3     2014-01-01 17:02:00  nighttime
# 4     2014-01-01 17:02:00  nighttime
# ...                   ...        ...
# 84451 2023-08-20 20:14:00    daytime
# 84452 2023-08-20 20:14:00    daytime
# 84453 2023-08-20 20:14:00  nighttime
# 84454 2023-08-20 20:14:00  nighttime
# 84455 2023-08-20 20:14:00  nighttime
#
# [84456 rows x 12 columns]

# %%
weather_data_final.to_csv('../../../raw_data/weather_data_final.csv')

# %% [markdown]
# ## 3. Add events to main dataframe

# %% [markdown]
# ### 3.1 Load the events_df

# %%
pwd
# Out:
# '/home/catherine/code/elsebasmar/london-bss/londonbss/notebooks/data_collection'

# %%
all_events_df = pd.read_csv("../../../raw_data/all_events_df.csv")

# %%
all_events_df
# Out:
#      Unnamed: 0                   title  start_date    end_date  \
# 0             0          New Year’s Day  2014-01-01  2014-01-01
# 1             1             Good Friday  2014-04-18  2014-04-18
# 2             2           Easter Monday  2014-04-21  2014-04-21
# 3             3  Early May bank holiday  2014-05-05  2014-05-05
# 4             4     Spring bank holiday  2014-05-26  2014-05-26
# ..          ...                     ...         ...         ...
# 943         943            FA cup final  2018-05-19  2018-05-19
# 944         944            FA cup final  2019-05-18  2019-05-18
# 945         945            FA cup final  2021-05-15  2021-05-15
# 946         946            FA cup final  2021-05-14  2021-05-14
# 947         947            FA cup final  2023-06-03  2023-06-03
#
#             Location     Latitude     Longitude
# 0        London-wide  London-wide   London-wide
# 1        London-wide  London-wide   London-wide
# 2        London-wide  London-wide   London-wide
# 3        London-wide  London-wide   London-wide
# 4        London-wide  London-wide   London-wide
# ..               ...          ...           ...
# 943  Wembley Stadium  51.55616476  -0.279596246
# 944  Wembley Stadium  51.55616476  -0.279596246
# 945  Wembley Stadium  51.55616476  -0.279596246
# 946  Wembley Stadium  51.55616476  -0.279596246
# 947  Wembley Stadium  51.55616476  -0.279596246
#
# [948 rows x 7 columns]

# %%
all_events_df.dtypes
# Out:
# Unnamed: 0     int64
# title         object
# start_date    object
# end_date      object
# Location      object
# Latitude      object
# Longitude     object
# dtype: object

# %%
all_events_df.drop("Unnamed: 0",axis =1, inplace=True)

# %%
all_events_df.columns
# Out:
# Index(['title', 'start_date', 'end_date', 'Location', 'Latitude', 'Longitude'], dtype='object')

# %%
new_column_list = ("event_title", "event_start_date", "event_end_date", "event_location", "event_latitude", "event_longitude")

# %%
all_events_df.columns = new_column_list

# %%
all_events_df["event_start_date"]= pd.to_datetime(all_events_df["event_start_date"])

# %%
all_events_df["event_end_date"]= pd.to_datetime(all_events_df["event_end_date"])

# %%
all_events_df['date'] = all_events_df['event_start_date'].dt.date

# %%
all_events_df.head()
# Out:
#               event_title event_start_date event_end_date event_location  \
# 0          New Year’s Day       2014-01-01     2014-01-01    London-wide
# 1             Good Friday       2014-04-18     2014-04-18    London-wide
# 2           Easter Monday       2014-04-21     2014-04-21    London-wide
# 3  Early May bank holiday       2014-05-05     2014-05-05    London-wide
# 4     Spring bank holiday       2014-05-26     2014-05-26    London-wide
#
#   event_latitude event_longitude        date
# 0    London-wide     London-wide  2014-01-01
# 1    London-wide     London-wide  2014-04-18
# 2    London-wide     London-wide  2014-04-21
# 3    London-wide     London-wide  2014-05-05
# 4    London-wide     London-wide  2014-05-26

# %% [markdown]
# ### 3.2 Merge with main df

# %%
weather_events_data = weather_data_final.copy()

# %%
weather_events_data.shape
# Out:
# (84456, 12)

# %%
weather_events_data = weather_events_data.merge(all_events_df, on="date", how="left")

# %%
weather_events_data.shape
# Out:
# (86784, 18)

# %%
weather_events_data.to_csv('../../../raw_data/weather_events_data.csv')

# %% [markdown]
# ## 4. Add Elisabeth line column

# %%
we_ev_el = weather_events_data.copy()

# %%
#Elisabeth line first day = 24/05/2022

# %%
we_ev_el["date"] = pd.to_datetime(we_ev_el["date"])

# %%
we_ev_el["elisabeth_line"] = "True"

# %%
we_ev_el.loc[we_ev_el["date"] < "2022-05-24", "elisabeth_line"] = False

# %%
we_ev_el.shape
# Out:
# (86784, 19)

# %%
we_ev_el.to_csv('../../../raw_data/we_ev_el.csv')

# %% [markdown]
# ## 5. Add lockdown column

# %%
# lockdown 1 = 24/03/2020 to 28/05/2020
# lockdown 2 = 05/11/2020 to 02/12/2020
# lockdown 3 = 04/01/2021 to 12/04/2021

# %%
weevel_lo = we_ev_el.copy()

# %%
from datetime import datetime

# %%
lockdown1_start = datetime.strptime("2020-03-24", '%Y-%m-%d')
lockdown1_end = datetime.strptime("2020-05-28", '%Y-%m-%d')
lockdown2_start = datetime.strptime("2020-11-05", '%Y-%m-%d')
lockdown2_end = datetime.strptime("2020-12-02", '%Y-%m-%d')
lockdown3_start = datetime.strptime("2021-01-04", '%Y-%m-%d')
lockdown3_end = datetime.strptime("2021-04-12", '%Y-%m-%d')

# %%
def lockdown_date(date):
    if date > lockdown1_start and date <= lockdown1_end:
        return True
    elif date > lockdown2_start and date <= lockdown2_end:
        return True
    elif date > lockdown3_start and date <= lockdown3_end:
        return True
    else:
        return False

# %%
# test_date = datetime.strptime("2020-12-13", '%Y-%m-%d')
# print(lockdown_date(test_date, True))
#weather_data["encoding"] = weather_data.apply(lambda x: daytime_encoding(x["timestamp"], x["sunrise_datetime"], x["sunset_datetime"]), axis = 1)

# %%
weevel_lo["lockdown"] = weevel_lo["date"].apply(lockdown_date)
weevel_lo.lockdown.value_counts()
# Out:
# lockdown
# False    82224
# True      4560
# Name: count, dtype: int64

# %%
weevel_lo.to_csv('../../../raw_data/weevel_lo.csv')

# %% [markdown]
# ## 6. School holidays

# %%
scho_hol = weevel_lo.copy()

# %%
school_holidays = pd.read_csv("../../../raw_data/school_holidays.csv")

# %%
school_holidays.columns
# Out:
# Index(['school_holidays', 'date'], dtype='object')

# %%
school_holidays["date"] = pd.to_datetime(school_holidays["date"])

# %%
scho_hol = scho_hol.merge(school_holidays, on="date", how="left")

# %%
scho_hol.head(100)
# Out:
#              timestamp  temperature  precipitation  rainfall  snowfall  \
# 0  2014-01-01 00:00:00          6.2            0.0       0.0       0.0
# 1  2014-01-01 01:00:00          6.4            0.0       0.0       0.0
# 2  2014-01-01 02:00:00          6.5            0.0       0.0       0.0
# 3  2014-01-01 03:00:00          6.5            0.0       0.0       0.0
# 4  2014-01-01 04:00:00          6.4            0.0       0.0       0.0
# ..                 ...          ...            ...       ...       ...
# 95 2014-01-04 23:00:00          3.5            0.0       0.0       0.0
# 96 2014-01-05 00:00:00          2.9            0.0       0.0       0.0
# 97 2014-01-05 01:00:00          2.5            0.0       0.0       0.0
# 98 2014-01-05 02:00:00          2.4            0.0       0.0       0.0
# 99 2014-01-05 03:00:00          2.5            0.0       0.0       0.0
#
#     cloudcover  wind_speed  wind_direction       date    sunrise_datetime  \
# 0           87        22.3             194 2014-01-01 2014-01-01 09:06:00
# 1          100        24.6             201 2014-01-01 2014-01-01 09:06:00
# 2           63        25.0             205 2014-01-01 2014-01-01 09:06:00
# 3           40        24.5             208 2014-01-01 2014-01-01 09:06:00
# 4           84        23.0             207 2014-01-01 2014-01-01 09:06:00
# ..         ...         ...             ...        ...                 ...
# 95           4        15.0             240 2014-01-04 2014-01-04 09:05:00
# 96           0        13.9             239 2014-01-05 2014-01-05 09:05:00
# 97          26        13.4             239 2014-01-05 2014-01-05 09:05:00
# 98          68        12.7             235 2014-01-05 2014-01-05 09:05:00
# 99          50        13.6             238 2014-01-05 2014-01-05 09:05:00
#
#     ...   encoding     event_title event_start_date event_end_date  \
# 0   ...  nighttime  New Year’s Day       2014-01-01     2014-01-01
# 1   ...  nighttime  New Year’s Day       2014-01-01     2014-01-01
# 2   ...  nighttime  New Year’s Day       2014-01-01     2014-01-01
# 3   ...  nighttime  New Year’s Day       2014-01-01     2014-01-01
# 4   ...  nighttime  New Year’s Day       2014-01-01     2014-01-01
# ..  ...        ...             ...              ...            ...
# 95  ...  nighttime             NaN              NaT            NaT
# 96  ...  nighttime             NaN              NaT            NaT
# 97  ...  nighttime             NaN              NaT            NaT
# 98  ...  nighttime             NaN              NaT            NaT
# 99  ...  nighttime             NaN              NaT            NaT
#
#    event_location event_latitude event_longitude elisabeth_line lockdown  \
# 0     London-wide    London-wide     London-wide          False    False
# 1     London-wide    London-wide     London-wide          False    False
# 2     London-wide    London-wide     London-wide          False    False
# 3     London-wide    London-wide     London-wide          False    False
# 4     London-wide    London-wide     London-wide          False    False
# ..            ...            ...             ...            ...      ...
# 95            NaN            NaN             NaN          False    False
# 96            NaN            NaN             NaN          False    False
# 97            NaN            NaN             NaN          False    False
# 98            NaN            NaN             NaN          False    False
# 99            NaN            NaN             NaN          False    False
#
#     school_holidays
# 0         christmas
# 1         christmas
# 2         christmas
# 3         christmas
# 4         christmas
# ..              ...
# 95        christmas
# 96        christmas
# 97        christmas
# 98        christmas
# 99        christmas
#
# [100 rows x 21 columns]

# %%
scho_hol.to_csv('../../../raw_data/scho_hol.csv')

# %% [markdown]
# ## 7. Strikes

# %%
strikes_df = scho_hol.copy()

# %%
strikes = pd.read_csv("../../../raw_data/strikes.csv")

# %%
strikes.columns
# Out:
# Index(['strike', 'date'], dtype='object')

# %%
strikes["date"] = pd.to_datetime(strikes["date"])

# %%
strikes_df = strikes_df.merge(strikes, on="date", how="left")

# %%
strikes_df.head()
# Out:
#             timestamp  temperature  precipitation  rainfall  snowfall  \
# 0 2014-01-01 00:00:00          6.2            0.0       0.0       0.0
# 1 2014-01-01 01:00:00          6.4            0.0       0.0       0.0
# 2 2014-01-01 02:00:00          6.5            0.0       0.0       0.0
# 3 2014-01-01 03:00:00          6.5            0.0       0.0       0.0
# 4 2014-01-01 04:00:00          6.4            0.0       0.0       0.0
#
#    cloudcover  wind_speed  wind_direction       date    sunrise_datetime  ...  \
# 0          87        22.3             194 2014-01-01 2014-01-01 09:06:00  ...
# 1         100        24.6             201 2014-01-01 2014-01-01 09:06:00  ...
# 2          63        25.0             205 2014-01-01 2014-01-01 09:06:00  ...
# 3          40        24.5             208 2014-01-01 2014-01-01 09:06:00  ...
# 4          84        23.0             207 2014-01-01 2014-01-01 09:06:00  ...
#
#       event_title event_start_date event_end_date event_location  \
# 0  New Year’s Day       2014-01-01     2014-01-01    London-wide
# 1  New Year’s Day       2014-01-01     2014-01-01    London-wide
# 2  New Year’s Day       2014-01-01     2014-01-01    London-wide
# 3  New Year’s Day       2014-01-01     2014-01-01    London-wide
# 4  New Year’s Day       2014-01-01     2014-01-01    London-wide
#
#   event_latitude event_longitude elisabeth_line lockdown school_holidays  \
# 0    London-wide     London-wide          False    False       christmas
# 1    London-wide     London-wide          False    False       christmas
# 2    London-wide     London-wide          False    False       christmas
# 3    London-wide     London-wide          False    False       christmas
# 4    London-wide     London-wide          False    False       christmas
#
#    strike
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#
# [5 rows x 22 columns]

# %%
strikes_df.to_csv('../../../raw_data/strikes_df.csv')

# %% [markdown]
# ## 8. Add weekday

# %%
weekday_df = strikes_df.copy()

# %%
def is_weekday(date):
    day_of_the_week = date.weekday()
    return day_of_the_week

# %%
weekday_df["weekday"] = weekday_df.apply(lambda x: is_weekday(x["timestamp"]), axis = 1)

# %%
weekday_df.head(50)
# Out:
#              timestamp  temperature  precipitation  rainfall  snowfall  \
# 0  2014-01-01 00:00:00          6.2            0.0       0.0       0.0
# 1  2014-01-01 01:00:00          6.4            0.0       0.0       0.0
# 2  2014-01-01 02:00:00          6.5            0.0       0.0       0.0
# 3  2014-01-01 03:00:00          6.5            0.0       0.0       0.0
# 4  2014-01-01 04:00:00          6.4            0.0       0.0       0.0
# 5  2014-01-01 05:00:00          6.2            0.0       0.0       0.0
# 6  2014-01-01 06:00:00          6.1            0.0       0.0       0.0
# 7  2014-01-01 07:00:00          6.4            0.0       0.0       0.0
# 8  2014-01-01 08:00:00          7.2            0.0       0.0       0.0
# 9  2014-01-01 09:00:00          7.3            0.0       0.0       0.0
# 10 2014-01-01 10:00:00          7.6            0.0       0.0       0.0
# 11 2014-01-01 11:00:00          7.8            0.5       0.5       0.0
# 12 2014-01-01 12:00:00          7.7            1.4       1.4       0.0
# 13 2014-01-01 13:00:00          7.8            1.9       1.9       0.0
# 14 2014-01-01 14:00:00          8.2            2.0       2.0       0.0
# 15 2014-01-01 15:00:00          8.8            1.1       1.1       0.0
# 16 2014-01-01 16:00:00          9.3            0.5       0.5       0.0
# 17 2014-01-01 17:00:00          9.6            1.0       1.0       0.0
# 18 2014-01-01 18:00:00          9.8            1.1       1.1       0.0
# 19 2014-01-01 19:00:00          9.9            0.4       0.4       0.0
# 20 2014-01-01 20:00:00          9.9            0.3       0.3       0.0
# 21 2014-01-01 21:00:00         10.0            0.2       0.2       0.0
# 22 2014-01-01 22:00:00         10.1            0.1       0.1       0.0
# 23 2014-01-01 23:00:00         10.0            0.9       0.9       0.0
# 24 2014-01-02 00:00:00          9.7            1.0       1.0       0.0
# 25 2014-01-02 01:00:00          8.9            0.2       0.2       0.0
# 26 2014-01-02 02:00:00          8.5            0.0       0.0       0.0
# 27 2014-01-02 03:00:00          8.3            0.0       0.0       0.0
# 28 2014-01-02 04:00:00          8.2            0.0       0.0       0.0
# 29 2014-01-02 05:00:00          8.0            0.0       0.0       0.0
# 30 2014-01-02 06:00:00          7.5            0.0       0.0       0.0
# 31 2014-01-02 07:00:00          7.1            0.0       0.0       0.0
# 32 2014-01-02 08:00:00          5.8            0.0       0.0       0.0
# 33 2014-01-02 09:00:00          5.4            0.0       0.0       0.0
# 34 2014-01-02 10:00:00          5.5            0.0       0.0       0.0
# 35 2014-01-02 11:00:00          6.3            0.0       0.0       0.0
# 36 2014-01-02 12:00:00          7.5            0.0       0.0       0.0
# 37 2014-01-02 13:00:00          8.4            0.0       0.0       0.0
# 38 2014-01-02 14:00:00          9.0            0.0       0.0       0.0
# 39 2014-01-02 15:00:00          9.2            0.0       0.0       0.0
# 40 2014-01-02 16:00:00          8.9            0.0       0.0       0.0
# 41 2014-01-02 17:00:00          8.2            0.0       0.0       0.0
# 42 2014-01-02 18:00:00          7.4            0.0       0.0       0.0
# 43 2014-01-02 19:00:00          7.3            0.0       0.0       0.0
# 44 2014-01-02 20:00:00          7.9            0.0       0.0       0.0
# 45 2014-01-02 21:00:00          8.4            0.0       0.0       0.0
# 46 2014-01-02 22:00:00          8.7            0.0       0.0       0.0
# 47 2014-01-02 23:00:00          8.9            0.3       0.3       0.0
# 48 2014-01-03 00:00:00          8.9            0.8       0.8       0.0
# 49 2014-01-03 01:00:00          9.1            0.9       0.9       0.0
#
#     cloudcover  wind_speed  wind_direction       date    sunrise_datetime  \
# 0           87        22.3             194 2014-01-01 2014-01-01 09:06:00
# 1          100        24.6             201 2014-01-01 2014-01-01 09:06:00
# 2           63        25.0             205 2014-01-01 2014-01-01 09:06:00
# 3           40        24.5             208 2014-01-01 2014-01-01 09:06:00
# 4           84        23.0             207 2014-01-01 2014-01-01 09:06:00
# 5           73        22.6             205 2014-01-01 2014-01-01 09:06:00
# 6           79        21.8             202 2014-01-01 2014-01-01 09:06:00
# 7           71        21.9             197 2014-01-01 2014-01-01 09:06:00
# 8          100        23.2             192 2014-01-01 2014-01-01 09:06:00
# 9          100        26.0             185 2014-01-01 2014-01-01 09:06:00
# 10         100        28.5             178 2014-01-01 2014-01-01 09:06:00
# 11         100        31.6             172 2014-01-01 2014-01-01 09:06:00
# 12         100        35.1             170 2014-01-01 2014-01-01 09:06:00
# 13         100        37.4             164 2014-01-01 2014-01-01 09:06:00
# 14         100        38.5             169 2014-01-01 2014-01-01 09:06:00
# 15         100        37.1             181 2014-01-01 2014-01-01 09:06:00
# 16         100        40.0             188 2014-01-01 2014-01-01 09:06:00
# 17         100        38.3             185 2014-01-01 2014-01-01 09:06:00
# 18         100        35.3             182 2014-01-01 2014-01-01 09:06:00
# 19         100        33.3             191 2014-01-01 2014-01-01 09:06:00
# 20         100        32.7             191 2014-01-01 2014-01-01 09:06:00
# 21         100        33.0             194 2014-01-01 2014-01-01 09:06:00
# 22         100        31.9             198 2014-01-01 2014-01-01 09:06:00
# 23          81        27.9             195 2014-01-01 2014-01-01 09:06:00
# 24          70        26.6             205 2014-01-02 2014-01-02 09:06:00
# 25          69        24.3             207 2014-01-02 2014-01-02 09:06:00
# 26          82        23.4             205 2014-01-02 2014-01-02 09:06:00
# 27          90        24.2             203 2014-01-02 2014-01-02 09:06:00
# 28         100        20.9             209 2014-01-02 2014-01-02 09:06:00
# 29         100        18.7             236 2014-01-02 2014-01-02 09:06:00
# 30          50        19.5             258 2014-01-02 2014-01-02 09:06:00
# 31          16        18.5             257 2014-01-02 2014-01-02 09:06:00
# 32           7        18.6             248 2014-01-02 2014-01-02 09:06:00
# 33           1        17.7             241 2014-01-02 2014-01-02 09:06:00
# 34           1        17.6             235 2014-01-02 2014-01-02 09:06:00
# 35           1        16.0             224 2014-01-02 2014-01-02 09:06:00
# 36           0        14.9             217 2014-01-02 2014-01-02 09:06:00
# 37           0        16.1             214 2014-01-02 2014-01-02 09:06:00
# 38           2        17.0             212 2014-01-02 2014-01-02 09:06:00
# 39          26        19.7             211 2014-01-02 2014-01-02 09:06:00
# 40          53        20.0             206 2014-01-02 2014-01-02 09:06:00
# 41          40        20.5             204 2014-01-02 2014-01-02 09:06:00
# 42          38        19.9             200 2014-01-02 2014-01-02 09:06:00
# 43          41        20.3             197 2014-01-02 2014-01-02 09:06:00
# 44          72        21.0             192 2014-01-02 2014-01-02 09:06:00
# 45          51        22.5             187 2014-01-02 2014-01-02 09:06:00
# 46          64        24.2             184 2014-01-02 2014-01-02 09:06:00
# 47          89        27.4             179 2014-01-02 2014-01-02 09:06:00
# 48         100        30.6             180 2014-01-03 2014-01-03 09:06:00
# 49         100        33.8             181 2014-01-03 2014-01-03 09:06:00
#
#     ... event_start_date event_end_date event_location event_latitude  \
# 0   ...       2014-01-01     2014-01-01    London-wide    London-wide
# 1   ...       2014-01-01     2014-01-01    London-wide    London-wide
# 2   ...       2014-01-01     2014-01-01    London-wide    London-wide
# 3   ...       2014-01-01     2014-01-01    London-wide    London-wide
# 4   ...       2014-01-01     2014-01-01    London-wide    London-wide
# 5   ...       2014-01-01     2014-01-01    London-wide    London-wide
# 6   ...       2014-01-01     2014-01-01    London-wide    London-wide
# 7   ...       2014-01-01     2014-01-01    London-wide    London-wide
# 8   ...       2014-01-01     2014-01-01    London-wide    London-wide
# 9   ...       2014-01-01     2014-01-01    London-wide    London-wide
# 10  ...       2014-01-01     2014-01-01    London-wide    London-wide
# 11  ...       2014-01-01     2014-01-01    London-wide    London-wide
# 12  ...       2014-01-01     2014-01-01    London-wide    London-wide
# 13  ...       2014-01-01     2014-01-01    London-wide    London-wide
# 14  ...       2014-01-01     2014-01-01    London-wide    London-wide
# 15  ...       2014-01-01     2014-01-01    London-wide    London-wide
# 16  ...       2014-01-01     2014-01-01    London-wide    London-wide
# 17  ...       2014-01-01     2014-01-01    London-wide    London-wide
# 18  ...       2014-01-01     2014-01-01    London-wide    London-wide
# 19  ...       2014-01-01     2014-01-01    London-wide    London-wide
# 20  ...       2014-01-01     2014-01-01    London-wide    London-wide
# 21  ...       2014-01-01     2014-01-01    London-wide    London-wide
# 22  ...       2014-01-01     2014-01-01    London-wide    London-wide
# 23  ...       2014-01-01     2014-01-01    London-wide    London-wide
# 24  ...              NaT            NaT            NaN            NaN
# 25  ...              NaT            NaT            NaN            NaN
# 26  ...              NaT            NaT            NaN            NaN
# 27  ...              NaT            NaT            NaN            NaN
# 28  ...              NaT            NaT            NaN            NaN
# 29  ...              NaT            NaT            NaN            NaN
# 30  ...              NaT            NaT            NaN            NaN
# 31  ...              NaT            NaT            NaN            NaN
# 32  ...              NaT            NaT            NaN            NaN
# 33  ...              NaT            NaT            NaN            NaN
# 34  ...              NaT            NaT            NaN            NaN
# 35  ...              NaT            NaT            NaN            NaN
# 36  ...              NaT            NaT            NaN            NaN
# 37  ...              NaT            NaT            NaN            NaN
# 38  ...              NaT            NaT            NaN            NaN
# 39  ...              NaT            NaT            NaN            NaN
# 40  ...              NaT            NaT            NaN            NaN
# 41  ...              NaT            NaT            NaN            NaN
# 42  ...              NaT            NaT            NaN            NaN
# 43  ...              NaT            NaT            NaN            NaN
# 44  ...              NaT            NaT            NaN            NaN
# 45  ...              NaT            NaT            NaN            NaN
# 46  ...              NaT            NaT            NaN            NaN
# 47  ...              NaT            NaT            NaN            NaN
# 48  ...              NaT            NaT            NaN            NaN
# 49  ...              NaT            NaT            NaN            NaN
#
#    event_longitude elisabeth_line lockdown school_holidays strike  weekday
# 0      London-wide          False    False       christmas    NaN        2
# 1      London-wide          False    False       christmas    NaN        2
# 2      London-wide          False    False       christmas    NaN        2
# 3      London-wide          False    False       christmas    NaN        2
# 4      London-wide          False    False       christmas    NaN        2
# 5      London-wide          False    False       christmas    NaN        2
# 6      London-wide          False    False       christmas    NaN        2
# 7      London-wide          False    False       christmas    NaN        2
# 8      London-wide          False    False       christmas    NaN        2
# 9      London-wide          False    False       christmas    NaN        2
# 10     London-wide          False    False       christmas    NaN        2
# 11     London-wide          False    False       christmas    NaN        2
# 12     London-wide          False    False       christmas    NaN        2
# 13     London-wide          False    False       christmas    NaN        2
# 14     London-wide          False    False       christmas    NaN        2
# 15     London-wide          False    False       christmas    NaN        2
# 16     London-wide          False    False       christmas    NaN        2
# 17     London-wide          False    False       christmas    NaN        2
# 18     London-wide          False    False       christmas    NaN        2
# 19     London-wide          False    False       christmas    NaN        2
# 20     London-wide          False    False       christmas    NaN        2
# 21     London-wide          False    False       christmas    NaN        2
# 22     London-wide          False    False       christmas    NaN        2
# 23     London-wide          False    False       christmas    NaN        2
# 24             NaN          False    False       christmas    NaN        3
# 25             NaN          False    False       christmas    NaN        3
# 26             NaN          False    False       christmas    NaN        3
# 27             NaN          False    False       christmas    NaN        3
# 28             NaN          False    False       christmas    NaN        3
# 29             NaN          False    False       christmas    NaN        3
# 30             NaN          False    False       christmas    NaN        3
# 31             NaN          False    False       christmas    NaN        3
# 32             NaN          False    False       christmas    NaN        3
# 33             NaN          False    False       christmas    NaN        3
# 34             NaN          False    False       christmas    NaN        3
# 35             NaN          False    False       christmas    NaN        3
# 36             NaN          False    False       christmas    NaN        3
# 37             NaN          False    False       christmas    NaN        3
# 38             NaN          False    False       christmas    NaN        3
# 39             NaN          False    False       christmas    NaN        3
# 40             NaN          False    False       christmas    NaN        3
# 41             NaN          False    False       christmas    NaN        3
# 42             NaN          False    False       christmas    NaN        3
# 43             NaN          False    False       christmas    NaN        3
# 44             NaN          False    False       christmas    NaN        3
# 45             NaN          False    False       christmas    NaN        3
# 46             NaN          False    False       christmas    NaN        3
# 47             NaN          False    False       christmas    NaN        3
# 48             NaN          False    False       christmas    NaN        4
# 49             NaN          False    False       christmas    NaN        4
#
# [50 rows x 23 columns]

# %% [markdown]
# ## Final df export

# %%
final_features_df = weekday_df.copy()

# %%
final_features_df.shape
# Out:
# (86904, 23)

# %%
final_features_df.to_csv('../../../raw_data/final_features_df.csv')
