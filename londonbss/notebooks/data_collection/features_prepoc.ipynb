# %% [markdown]
# # Features preprocessing

# %% [markdown]
# ## 1. MinMax scale

# %%
from sklearn.preprocessing import MinMaxScaler
import pandas as pd
import numpy as np
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from datetime import datetime
import pygeohash as pgh

# %%
pwd
# Out:
# '/home/catherine/code/elsebasmar/london-bss/londonbss/notebooks/data_collection'

# %%
data = pd.read_csv("../../../raw_data/final_features_df.csv")

# %%
data.head()
# Out:
#    Unnamed: 0            timestamp  temperature  precipitation  rainfall  \
# 0           0  2022-01-02 00:00:00         12.5            0.1       0.1
# 1           1  2022-01-02 01:00:00         12.4            0.1       0.1
# 2           2  2022-01-02 02:00:00         12.4            0.0       0.0
# 3           3  2022-01-02 03:00:00         12.4            0.0       0.0
# 4           4  2022-01-02 04:00:00         12.4            0.0       0.0
#
#    snowfall  cloudcover  wind_speed  wind_direction        date  ...  \
# 0       0.0         100         6.9             189  2022-01-02  ...
# 1       0.0         100        20.2             239  2022-01-02  ...
# 2       0.0         100        19.0             241  2022-01-02  ...
# 3       0.0         100        17.4             248  2022-01-02  ...
# 4       0.0         100        17.4             248  2022-01-02  ...
#
#   London_zone_South_East London_zone_East London_zone_London_all  \
# 0                    NaN              NaN                    NaN
# 1                    NaN              NaN                    NaN
# 2                    NaN              NaN                    NaN
# 3                    NaN              NaN                    NaN
# 4                    NaN              NaN                    NaN
#
#   London_zone_North London_zone_South_West London_zone_West elisabeth_line  \
# 0               NaN                    NaN              NaN          False
# 1               NaN                    NaN              NaN          False
# 2               NaN                    NaN              NaN          False
# 3               NaN                    NaN              NaN          False
# 4               NaN                    NaN              NaN          False
#
#   lockdown school_holidays  strike
# 0    False       christmas     NaN
# 1    False       christmas     NaN
# 2    False       christmas     NaN
# 3    False       christmas     NaN
# 4    False       christmas     NaN
#
# [5 rows x 30 columns]

# %%
scaler = MinMaxScaler()
data["temperature"] = scaler.fit(data[['temperature']])
data["rainfall"] = scaler.fit(data[['rainfall']])
data["snowfall"] = scaler.fit(data[['snowfall']])
data["cloudcover"] = scaler.fit(data[['cloudcover']])
data["wind_speed"] = scaler.fit(data[['wind_speed']])
data["wind_direction"] = scaler.fit(data[['wind_direction']])

# %%
data.head()
# Out:
#    Unnamed: 0            timestamp     temperature  precipitation  \
# 0           0  2022-01-02 00:00:00  MinMaxScaler()            0.1
# 1           1  2022-01-02 01:00:00  MinMaxScaler()            0.1
# 2           2  2022-01-02 02:00:00  MinMaxScaler()            0.0
# 3           3  2022-01-02 03:00:00  MinMaxScaler()            0.0
# 4           4  2022-01-02 04:00:00  MinMaxScaler()            0.0
#
#          rainfall        snowfall      cloudcover      wind_speed  \
# 0  MinMaxScaler()  MinMaxScaler()  MinMaxScaler()  MinMaxScaler()
# 1  MinMaxScaler()  MinMaxScaler()  MinMaxScaler()  MinMaxScaler()
# 2  MinMaxScaler()  MinMaxScaler()  MinMaxScaler()  MinMaxScaler()
# 3  MinMaxScaler()  MinMaxScaler()  MinMaxScaler()  MinMaxScaler()
# 4  MinMaxScaler()  MinMaxScaler()  MinMaxScaler()  MinMaxScaler()
#
#    wind_direction        date  ... London_zone_South_East London_zone_East  \
# 0  MinMaxScaler()  2022-01-02  ...                    NaN              NaN
# 1  MinMaxScaler()  2022-01-02  ...                    NaN              NaN
# 2  MinMaxScaler()  2022-01-02  ...                    NaN              NaN
# 3  MinMaxScaler()  2022-01-02  ...                    NaN              NaN
# 4  MinMaxScaler()  2022-01-02  ...                    NaN              NaN
#
#   London_zone_London_all London_zone_North London_zone_South_West  \
# 0                    NaN               NaN                    NaN
# 1                    NaN               NaN                    NaN
# 2                    NaN               NaN                    NaN
# 3                    NaN               NaN                    NaN
# 4                    NaN               NaN                    NaN
#
#   London_zone_West elisabeth_line lockdown school_holidays  strike
# 0              NaN          False    False       christmas     NaN
# 1              NaN          False    False       christmas     NaN
# 2              NaN          False    False       christmas     NaN
# 3              NaN          False    False       christmas     NaN
# 4              NaN          False    False       christmas     NaN
#
# [5 rows x 30 columns]

# %%
scaled_data = data

# %% [markdown]
# ## 2. Add dates details columns

# %%
scaled_data["year"] = scaled_data["timestamp"].str[:4]
scaled_data["month"] = scaled_data["timestamp"].str[6:7]
scaled_data["day"] = scaled_data["timestamp"].str[9:10]
scaled_data["hour"] = scaled_data["timestamp"].str[12:13]
scaled_data["minute"] = scaled_data["timestamp"].str[15:16]
scaled_data["second"] = scaled_data["timestamp"].str[18:19]

# %%
scaled_data.head()
# Out:
#    Unnamed: 0            timestamp     temperature  precipitation  \
# 0           0  2022-01-02 00:00:00  MinMaxScaler()            0.1
# 1           1  2022-01-02 01:00:00  MinMaxScaler()            0.1
# 2           2  2022-01-02 02:00:00  MinMaxScaler()            0.0
# 3           3  2022-01-02 03:00:00  MinMaxScaler()            0.0
# 4           4  2022-01-02 04:00:00  MinMaxScaler()            0.0
#
#          rainfall        snowfall      cloudcover      wind_speed  \
# 0  MinMaxScaler()  MinMaxScaler()  MinMaxScaler()  MinMaxScaler()
# 1  MinMaxScaler()  MinMaxScaler()  MinMaxScaler()  MinMaxScaler()
# 2  MinMaxScaler()  MinMaxScaler()  MinMaxScaler()  MinMaxScaler()
# 3  MinMaxScaler()  MinMaxScaler()  MinMaxScaler()  MinMaxScaler()
# 4  MinMaxScaler()  MinMaxScaler()  MinMaxScaler()  MinMaxScaler()
#
#    wind_direction        date  ... elisabeth_line lockdown school_holidays  \
# 0  MinMaxScaler()  2022-01-02  ...          False    False       christmas
# 1  MinMaxScaler()  2022-01-02  ...          False    False       christmas
# 2  MinMaxScaler()  2022-01-02  ...          False    False       christmas
# 3  MinMaxScaler()  2022-01-02  ...          False    False       christmas
# 4  MinMaxScaler()  2022-01-02  ...          False    False       christmas
#
#   strike  year month day hour minute  second
# 0    NaN  2022     1   2    0      0       0
# 1    NaN  2022     1   2    1      0       0
# 2    NaN  2022     1   2    2      0       0
# 3    NaN  2022     1   2    3      0       0
# 4    NaN  2022     1   2    4      0       0
#
# [5 rows x 36 columns]

# %%
scaled_data.drop(columns="Unnamed: 0", inplace=True)

# %%
scaled_data["timestamp"] = pd.to_datetime(scaled_data["timestamp"])

# %%
scaled_data.dtypes
# Out:
# timestamp                 datetime64[ns]
# temperature                       object
# precipitation                    float64
# rainfall                          object
# snowfall                          object
# cloudcover                        object
# wind_speed                        object
# wind_direction                    object
# date                              object
# sunrise_datetime                  object
# sunset_datetime                   object
# encoding                          object
# event_title                       object
# event_start_date                  object
# event_end_date                    object
# event_location                    object
# event_latitude                    object
# event_longitude                   object
# London_zone_Central              float64
# London_zone_South_East           float64
# London_zone_East                 float64
# London_zone_London_all           float64
# London_zone_North                float64
# London_zone_South_West           float64
# London_zone_West                 float64
# elisabeth_line                      bool
# lockdown                            bool
# school_holidays                   object
# strike                            object
# year                              object
# month                             object
# day                               object
# hour                              object
# minute                            object
# second                            object
# dtype: object

# %%
scaled_data["weekday"] = scaled_data["timestamp"].dt.weekday

# %%
scaled_data.set_index("timestamp", inplace=True)

# %%
scaled_data.head()
# Out:
#                         temperature  precipitation        rainfall  \
# timestamp
# 2022-01-02 00:00:00  MinMaxScaler()            0.1  MinMaxScaler()
# 2022-01-02 01:00:00  MinMaxScaler()            0.1  MinMaxScaler()
# 2022-01-02 02:00:00  MinMaxScaler()            0.0  MinMaxScaler()
# 2022-01-02 03:00:00  MinMaxScaler()            0.0  MinMaxScaler()
# 2022-01-02 04:00:00  MinMaxScaler()            0.0  MinMaxScaler()
#
#                            snowfall      cloudcover      wind_speed  \
# timestamp
# 2022-01-02 00:00:00  MinMaxScaler()  MinMaxScaler()  MinMaxScaler()
# 2022-01-02 01:00:00  MinMaxScaler()  MinMaxScaler()  MinMaxScaler()
# 2022-01-02 02:00:00  MinMaxScaler()  MinMaxScaler()  MinMaxScaler()
# 2022-01-02 03:00:00  MinMaxScaler()  MinMaxScaler()  MinMaxScaler()
# 2022-01-02 04:00:00  MinMaxScaler()  MinMaxScaler()  MinMaxScaler()
#
#                      wind_direction        date     sunrise_datetime  \
# timestamp
# 2022-01-02 00:00:00  MinMaxScaler()  2022-01-02  2022-01-02 09:06:00
# 2022-01-02 01:00:00  MinMaxScaler()  2022-01-02  2022-01-02 09:06:00
# 2022-01-02 02:00:00  MinMaxScaler()  2022-01-02  2022-01-02 09:06:00
# 2022-01-02 03:00:00  MinMaxScaler()  2022-01-02  2022-01-02 09:06:00
# 2022-01-02 04:00:00  MinMaxScaler()  2022-01-02  2022-01-02 09:06:00
#
#                          sunset_datetime  ... lockdown school_holidays strike  \
# timestamp                                 ...
# 2022-01-02 00:00:00  2022-01-02 17:03:00  ...    False       christmas    NaN
# 2022-01-02 01:00:00  2022-01-02 17:03:00  ...    False       christmas    NaN
# 2022-01-02 02:00:00  2022-01-02 17:03:00  ...    False       christmas    NaN
# 2022-01-02 03:00:00  2022-01-02 17:03:00  ...    False       christmas    NaN
# 2022-01-02 04:00:00  2022-01-02 17:03:00  ...    False       christmas    NaN
#
#                      year month day hour  minute  second  weekday
# timestamp
# 2022-01-02 00:00:00  2022     1   2    0       0       0        6
# 2022-01-02 01:00:00  2022     1   2    1       0       0        6
# 2022-01-02 02:00:00  2022     1   2    2       0       0        6
# 2022-01-02 03:00:00  2022     1   2    3       0       0        6
# 2022-01-02 04:00:00  2022     1   2    4       0       0        6
#
# [5 rows x 35 columns]

# %% [markdown]
# ## 3. Drop columns

# %%
droped_data = scaled_data.drop(columns=['precipitation','date','sunrise_datetime','sunset_datetime','event_start_date','event_end_date','event_start_date','event_location'])

# %%
droped_data.shape
# Out:
# (9192, 28)

# %%
droped_data.head()
# Out:
#                         temperature        rainfall        snowfall  \
# timestamp
# 2022-01-02 00:00:00  MinMaxScaler()  MinMaxScaler()  MinMaxScaler()
# 2022-01-02 01:00:00  MinMaxScaler()  MinMaxScaler()  MinMaxScaler()
# 2022-01-02 02:00:00  MinMaxScaler()  MinMaxScaler()  MinMaxScaler()
# 2022-01-02 03:00:00  MinMaxScaler()  MinMaxScaler()  MinMaxScaler()
# 2022-01-02 04:00:00  MinMaxScaler()  MinMaxScaler()  MinMaxScaler()
#
#                          cloudcover      wind_speed  wind_direction  \
# timestamp
# 2022-01-02 00:00:00  MinMaxScaler()  MinMaxScaler()  MinMaxScaler()
# 2022-01-02 01:00:00  MinMaxScaler()  MinMaxScaler()  MinMaxScaler()
# 2022-01-02 02:00:00  MinMaxScaler()  MinMaxScaler()  MinMaxScaler()
# 2022-01-02 03:00:00  MinMaxScaler()  MinMaxScaler()  MinMaxScaler()
# 2022-01-02 04:00:00  MinMaxScaler()  MinMaxScaler()  MinMaxScaler()
#
#                       encoding event_title event_latitude event_longitude  \
# timestamp
# 2022-01-02 00:00:00  nighttime         NaN            NaN             NaN
# 2022-01-02 01:00:00  nighttime         NaN            NaN             NaN
# 2022-01-02 02:00:00  nighttime         NaN            NaN             NaN
# 2022-01-02 03:00:00  nighttime         NaN            NaN             NaN
# 2022-01-02 04:00:00  nighttime         NaN            NaN             NaN
#
#                      ...  lockdown  school_holidays  strike  year  month  day  \
# timestamp            ...
# 2022-01-02 00:00:00  ...     False        christmas     NaN  2022      1    2
# 2022-01-02 01:00:00  ...     False        christmas     NaN  2022      1    2
# 2022-01-02 02:00:00  ...     False        christmas     NaN  2022      1    2
# 2022-01-02 03:00:00  ...     False        christmas     NaN  2022      1    2
# 2022-01-02 04:00:00  ...     False        christmas     NaN  2022      1    2
#
#                      hour  minute  second weekday
# timestamp
# 2022-01-02 00:00:00     0       0       0       6
# 2022-01-02 01:00:00     1       0       0       6
# 2022-01-02 02:00:00     2       0       0       6
# 2022-01-02 03:00:00     3       0       0       6
# 2022-01-02 04:00:00     4       0       0       6
#
# [5 rows x 28 columns]

# %% [markdown]
# ## 4.Day / night time encoding

# %%
dnte_data = droped_data.copy()
dnte_data.head()
# Out:
#                         temperature        rainfall        snowfall  \
# timestamp
# 2022-01-02 00:00:00  MinMaxScaler()  MinMaxScaler()  MinMaxScaler()
# 2022-01-02 01:00:00  MinMaxScaler()  MinMaxScaler()  MinMaxScaler()
# 2022-01-02 02:00:00  MinMaxScaler()  MinMaxScaler()  MinMaxScaler()
# 2022-01-02 03:00:00  MinMaxScaler()  MinMaxScaler()  MinMaxScaler()
# 2022-01-02 04:00:00  MinMaxScaler()  MinMaxScaler()  MinMaxScaler()
#
#                          cloudcover      wind_speed  wind_direction  \
# timestamp
# 2022-01-02 00:00:00  MinMaxScaler()  MinMaxScaler()  MinMaxScaler()
# 2022-01-02 01:00:00  MinMaxScaler()  MinMaxScaler()  MinMaxScaler()
# 2022-01-02 02:00:00  MinMaxScaler()  MinMaxScaler()  MinMaxScaler()
# 2022-01-02 03:00:00  MinMaxScaler()  MinMaxScaler()  MinMaxScaler()
# 2022-01-02 04:00:00  MinMaxScaler()  MinMaxScaler()  MinMaxScaler()
#
#                       encoding event_title event_latitude event_longitude  \
# timestamp
# 2022-01-02 00:00:00  nighttime         NaN            NaN             NaN
# 2022-01-02 01:00:00  nighttime         NaN            NaN             NaN
# 2022-01-02 02:00:00  nighttime         NaN            NaN             NaN
# 2022-01-02 03:00:00  nighttime         NaN            NaN             NaN
# 2022-01-02 04:00:00  nighttime         NaN            NaN             NaN
#
#                      ...  lockdown  school_holidays  strike  year  month  day  \
# timestamp            ...
# 2022-01-02 00:00:00  ...     False        christmas     NaN  2022      1    2
# 2022-01-02 01:00:00  ...     False        christmas     NaN  2022      1    2
# 2022-01-02 02:00:00  ...     False        christmas     NaN  2022      1    2
# 2022-01-02 03:00:00  ...     False        christmas     NaN  2022      1    2
# 2022-01-02 04:00:00  ...     False        christmas     NaN  2022      1    2
#
#                      hour  minute  second weekday
# timestamp
# 2022-01-02 00:00:00     0       0       0       6
# 2022-01-02 01:00:00     1       0       0       6
# 2022-01-02 02:00:00     2       0       0       6
# 2022-01-02 03:00:00     3       0       0       6
# 2022-01-02 04:00:00     4       0       0       6
#
# [5 rows x 28 columns]

# %%
dnte_data.rename(columns={"encoding": "daytime"}, inplace=True)

# %%
dnte_data.head()
# Out:
#                         temperature        rainfall        snowfall  \
# timestamp
# 2022-01-02 00:00:00  MinMaxScaler()  MinMaxScaler()  MinMaxScaler()
# 2022-01-02 01:00:00  MinMaxScaler()  MinMaxScaler()  MinMaxScaler()
# 2022-01-02 02:00:00  MinMaxScaler()  MinMaxScaler()  MinMaxScaler()
# 2022-01-02 03:00:00  MinMaxScaler()  MinMaxScaler()  MinMaxScaler()
# 2022-01-02 04:00:00  MinMaxScaler()  MinMaxScaler()  MinMaxScaler()
#
#                          cloudcover      wind_speed  wind_direction  \
# timestamp
# 2022-01-02 00:00:00  MinMaxScaler()  MinMaxScaler()  MinMaxScaler()
# 2022-01-02 01:00:00  MinMaxScaler()  MinMaxScaler()  MinMaxScaler()
# 2022-01-02 02:00:00  MinMaxScaler()  MinMaxScaler()  MinMaxScaler()
# 2022-01-02 03:00:00  MinMaxScaler()  MinMaxScaler()  MinMaxScaler()
# 2022-01-02 04:00:00  MinMaxScaler()  MinMaxScaler()  MinMaxScaler()
#
#                        daytime event_title event_latitude event_longitude  \
# timestamp
# 2022-01-02 00:00:00  nighttime         NaN            NaN             NaN
# 2022-01-02 01:00:00  nighttime         NaN            NaN             NaN
# 2022-01-02 02:00:00  nighttime         NaN            NaN             NaN
# 2022-01-02 03:00:00  nighttime         NaN            NaN             NaN
# 2022-01-02 04:00:00  nighttime         NaN            NaN             NaN
#
#                      ...  lockdown  school_holidays  strike  year  month  day  \
# timestamp            ...
# 2022-01-02 00:00:00  ...     False        christmas     NaN  2022      1    2
# 2022-01-02 01:00:00  ...     False        christmas     NaN  2022      1    2
# 2022-01-02 02:00:00  ...     False        christmas     NaN  2022      1    2
# 2022-01-02 03:00:00  ...     False        christmas     NaN  2022      1    2
# 2022-01-02 04:00:00  ...     False        christmas     NaN  2022      1    2
#
#                      hour  minute  second weekday
# timestamp
# 2022-01-02 00:00:00     0       0       0       6
# 2022-01-02 01:00:00     1       0       0       6
# 2022-01-02 02:00:00     2       0       0       6
# 2022-01-02 03:00:00     3       0       0       6
# 2022-01-02 04:00:00     4       0       0       6
#
# [5 rows x 28 columns]

# %%
dnte_data["daytime"].value_counts()
# Out:
# daytime
# daytime      4698
# nighttime    4494
# Name: count, dtype: int64

# %%
dnte_data["daytime"].value_counts()
# Out:
# daytime
# daytime      4698
# nighttime    4494
# Name: count, dtype: int64

# %%
dnte_data["daytime"] = dnte_data["daytime"].replace("daytime", "1")
dnte_data["daytime"] = dnte_data["daytime"].replace("nighttime", "0")

# %%
dnte_data["daytime"].astype("int")
# Out:
# timestamp
# 2022-01-02 00:00:00    0
# 2022-01-02 01:00:00    0
# 2022-01-02 02:00:00    0
# 2022-01-02 03:00:00    0
# 2022-01-02 04:00:00    0
#                       ..
# 2023-01-01 21:00:00    0
# 2023-01-01 22:00:00    0
# 2023-01-01 22:00:00    0
# 2023-01-01 23:00:00    0
# 2023-01-01 23:00:00    0
# Name: daytime, Length: 9192, dtype: int64

# %%
dnte_data["daytime"].value_counts()
# Out:
# daytime
# 1    4698
# 0    4494
# Name: count, dtype: int64

# %%
dnte_data.head()
# Out:
#                      temperature  rainfall  snowfall  cloudcover  wind_speed  \
# timestamp
# 2022-01-02 00:00:00     0.429952  0.010204       0.0         1.0    0.108333
# 2022-01-02 01:00:00     0.427536  0.010204       0.0         1.0    0.330000
# 2022-01-02 02:00:00     0.427536  0.000000       0.0         1.0    0.310000
# 2022-01-02 03:00:00     0.427536  0.000000       0.0         1.0    0.283333
# 2022-01-02 04:00:00     0.427536  0.000000       0.0         1.0    0.283333
#
#                      wind_direction daytime event_title event_latitude  \
# timestamp
# 2022-01-02 00:00:00        0.523677       0         NaN            NaN
# 2022-01-02 01:00:00        0.662953       0         NaN            NaN
# 2022-01-02 02:00:00        0.668524       0         NaN            NaN
# 2022-01-02 03:00:00        0.688022       0         NaN            NaN
# 2022-01-02 04:00:00        0.688022       0         NaN            NaN
#
#                     event_longitude  ...  lockdown  school_holidays  strike  \
# timestamp                            ...
# 2022-01-02 00:00:00             NaN  ...     False        christmas     NaN
# 2022-01-02 01:00:00             NaN  ...     False        christmas     NaN
# 2022-01-02 02:00:00             NaN  ...     False        christmas     NaN
# 2022-01-02 03:00:00             NaN  ...     False        christmas     NaN
# 2022-01-02 04:00:00             NaN  ...     False        christmas     NaN
#
#                      year  month  day  hour  minute  second weekday
# timestamp
# 2022-01-02 00:00:00  2022      1    2     0       0       0       6
# 2022-01-02 01:00:00  2022      1    2     1       0       0       6
# 2022-01-02 02:00:00  2022      1    2     2       0       0       6
# 2022-01-02 03:00:00  2022      1    2     3       0       0       6
# 2022-01-02 04:00:00  2022      1    2     4       0       0       6
#
# [5 rows x 28 columns]

# %% [markdown]
# ## 5. Event encoding

# %%
event_encoding = dnte_data.copy()

# %%
event_encoding.columns
# Out:
# Index(['temperature', 'rainfall', 'snowfall', 'cloudcover', 'wind_speed',
#        'wind_direction', 'daytime', 'event_title', 'event_latitude',
#        'event_longitude', 'London_zone_Central', 'London_zone_South_East',
#        'London_zone_East', 'London_zone_London_all', 'London_zone_North',
#        'London_zone_South_West', 'London_zone_West', 'elisabeth_line',
#        'lockdown', 'school_holidays', 'strike', 'year', 'month', 'day', 'hour',
#        'minute', 'second', 'weekday'],
#       dtype='object')

# %%
#event_encoding['event_title'] = event_encoding['event_title'].fillna(0)

# %%
event_encoding['event_title'].value_counts()
# Out:
# event_title
# Winter Wonderland                                           1104
# Wimbledon Tennis Championships                               336
# London Film Festival                                         288
# Frieze Art Fair                                              120
# Chelsea Flower Show                                          120
# Taste of London                                              120
# New Year’s Day                                                48
# Notting Hill Carnival                                         48
# Trooping the Colour                                           24
# Platinum Jubilee bank holiday                                 24
# Christmas Day                                                 24
# Boxing Day                                                    24
# World Cup 2022 1/4 final                                      24
# Easter Monday                                                 24
# Guy Fawkes Night (Bonfire Night)                              24
# Halloween in London                                           24
# Early May bank holiday                                        24
# Diwali on Trafalgar Square                                    24
# Survival Sunday (Premier League)                              24
# London Marathon                                               24
# Bank Holiday for the State Funeral of Queen Elizabeth II      24
# Summer bank holiday                                           24
# Good Friday                                                   24
# UEFA Women Euro Final                                         24
# Champions League Final                                        24
# Pride in London                                               24
# Spring bank holiday                                           24
# New Year's Eve Fireworks                                      24
# Name: count, dtype: int64

# %%
ohe = OneHotEncoder(sparse = False) 
ohe.fit(event_encoding[['event_title']]) 
event_encoding[ohe.get_feature_names_out()] = ohe.transform(event_encoding[['event_title']])
event_encoding.drop(columns = ["event_title"], inplace = True)
# Out:
# /home/catherine/.pyenv/versions/3.10.6/envs/london-bss/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
event_encoding.head()
# Out:
#                      temperature  rainfall  snowfall  cloudcover  wind_speed  \
# timestamp
# 2022-01-02 00:00:00     0.429952  0.010204       0.0         1.0    0.108333
# 2022-01-02 01:00:00     0.427536  0.010204       0.0         1.0    0.330000
# 2022-01-02 02:00:00     0.427536  0.000000       0.0         1.0    0.310000
# 2022-01-02 03:00:00     0.427536  0.000000       0.0         1.0    0.283333
# 2022-01-02 04:00:00     0.427536  0.000000       0.0         1.0    0.283333
#
#                      wind_direction daytime event_latitude event_longitude  \
# timestamp
# 2022-01-02 00:00:00        0.523677       0            NaN             NaN
# 2022-01-02 01:00:00        0.662953       0            NaN             NaN
# 2022-01-02 02:00:00        0.668524       0            NaN             NaN
# 2022-01-02 03:00:00        0.688022       0            NaN             NaN
# 2022-01-02 04:00:00        0.688022       0            NaN             NaN
#
#                      London_zone_Central  ...  \
# timestamp                                 ...
# 2022-01-02 00:00:00                  NaN  ...
# 2022-01-02 01:00:00                  NaN  ...
# 2022-01-02 02:00:00                  NaN  ...
# 2022-01-02 03:00:00                  NaN  ...
# 2022-01-02 04:00:00                  NaN  ...
#
#                      event_title_Spring bank holiday  \
# timestamp
# 2022-01-02 00:00:00                              0.0
# 2022-01-02 01:00:00                              0.0
# 2022-01-02 02:00:00                              0.0
# 2022-01-02 03:00:00                              0.0
# 2022-01-02 04:00:00                              0.0
#
#                      event_title_Summer bank holiday  \
# timestamp
# 2022-01-02 00:00:00                              0.0
# 2022-01-02 01:00:00                              0.0
# 2022-01-02 02:00:00                              0.0
# 2022-01-02 03:00:00                              0.0
# 2022-01-02 04:00:00                              0.0
#
#                      event_title_Survival Sunday (Premier League)  \
# timestamp
# 2022-01-02 00:00:00                                           0.0
# 2022-01-02 01:00:00                                           0.0
# 2022-01-02 02:00:00                                           0.0
# 2022-01-02 03:00:00                                           0.0
# 2022-01-02 04:00:00                                           0.0
#
#                      event_title_Taste of London  \
# timestamp
# 2022-01-02 00:00:00                          0.0
# 2022-01-02 01:00:00                          0.0
# 2022-01-02 02:00:00                          0.0
# 2022-01-02 03:00:00                          0.0
# 2022-01-02 04:00:00                          0.0
#
#                      event_title_Trooping the Colour  \
# timestamp
# 2022-01-02 00:00:00                              0.0
# 2022-01-02 01:00:00                              0.0
# 2022-01-02 02:00:00                              0.0
# 2022-01-02 03:00:00                              0.0
# 2022-01-02 04:00:00                              0.0
#
#                      event_title_UEFA Women Euro Final  \
# timestamp
# 2022-01-02 00:00:00                                0.0
# 2022-01-02 01:00:00                                0.0
# 2022-01-02 02:00:00                                0.0
# 2022-01-02 03:00:00                                0.0
# 2022-01-02 04:00:00                                0.0
#
#                      event_title_Wimbledon Tennis Championships  \
# timestamp
# 2022-01-02 00:00:00                                         0.0
# 2022-01-02 01:00:00                                         0.0
# 2022-01-02 02:00:00                                         0.0
# 2022-01-02 03:00:00                                         0.0
# 2022-01-02 04:00:00                                         0.0
#
#                      event_title_Winter Wonderland  \
# timestamp
# 2022-01-02 00:00:00                            0.0
# 2022-01-02 01:00:00                            0.0
# 2022-01-02 02:00:00                            0.0
# 2022-01-02 03:00:00                            0.0
# 2022-01-02 04:00:00                            0.0
#
#                     event_title_World Cup 2022 1/4 final event_title_nan
# timestamp
# 2022-01-02 00:00:00                                  0.0             1.0
# 2022-01-02 01:00:00                                  0.0             1.0
# 2022-01-02 02:00:00                                  0.0             1.0
# 2022-01-02 03:00:00                                  0.0             1.0
# 2022-01-02 04:00:00                                  0.0             1.0
#
# [5 rows x 56 columns]

# %%
def encoding_strings(text):
    if text == 0:
        pass
    else:
        text = 1
    return text

# %%
# event_encoding['event_title'] = event_encoding['event_title'].apply(encoding_strings)
# event_encoding['event_title'].value_counts()

# %%
event_encoding.shape
# Out:
# (9192, 56)

# %%
event_encoding = event_encoding.groupby('timestamp').sum()

# %%
event_encoding.shape
# Out:
# (8760, 56)

# %%
event_encoding.head()
# Out:
#                      temperature  rainfall  snowfall  cloudcover  wind_speed  \
# timestamp
# 2022-01-02 00:00:00     0.429952  0.010204       0.0         1.0    0.108333
# 2022-01-02 01:00:00     0.427536  0.010204       0.0         1.0    0.330000
# 2022-01-02 02:00:00     0.427536  0.000000       0.0         1.0    0.310000
# 2022-01-02 03:00:00     0.427536  0.000000       0.0         1.0    0.283333
# 2022-01-02 04:00:00     0.427536  0.000000       0.0         1.0    0.283333
#
#                      wind_direction daytime event_latitude event_longitude  \
# timestamp
# 2022-01-02 00:00:00        0.523677       0              0               0
# 2022-01-02 01:00:00        0.662953       0              0               0
# 2022-01-02 02:00:00        0.668524       0              0               0
# 2022-01-02 03:00:00        0.688022       0              0               0
# 2022-01-02 04:00:00        0.688022       0              0               0
#
#                      London_zone_Central  ...  \
# timestamp                                 ...
# 2022-01-02 00:00:00                  0.0  ...
# 2022-01-02 01:00:00                  0.0  ...
# 2022-01-02 02:00:00                  0.0  ...
# 2022-01-02 03:00:00                  0.0  ...
# 2022-01-02 04:00:00                  0.0  ...
#
#                      event_title_Spring bank holiday  \
# timestamp
# 2022-01-02 00:00:00                              0.0
# 2022-01-02 01:00:00                              0.0
# 2022-01-02 02:00:00                              0.0
# 2022-01-02 03:00:00                              0.0
# 2022-01-02 04:00:00                              0.0
#
#                      event_title_Summer bank holiday  \
# timestamp
# 2022-01-02 00:00:00                              0.0
# 2022-01-02 01:00:00                              0.0
# 2022-01-02 02:00:00                              0.0
# 2022-01-02 03:00:00                              0.0
# 2022-01-02 04:00:00                              0.0
#
#                      event_title_Survival Sunday (Premier League)  \
# timestamp
# 2022-01-02 00:00:00                                           0.0
# 2022-01-02 01:00:00                                           0.0
# 2022-01-02 02:00:00                                           0.0
# 2022-01-02 03:00:00                                           0.0
# 2022-01-02 04:00:00                                           0.0
#
#                      event_title_Taste of London  \
# timestamp
# 2022-01-02 00:00:00                          0.0
# 2022-01-02 01:00:00                          0.0
# 2022-01-02 02:00:00                          0.0
# 2022-01-02 03:00:00                          0.0
# 2022-01-02 04:00:00                          0.0
#
#                      event_title_Trooping the Colour  \
# timestamp
# 2022-01-02 00:00:00                              0.0
# 2022-01-02 01:00:00                              0.0
# 2022-01-02 02:00:00                              0.0
# 2022-01-02 03:00:00                              0.0
# 2022-01-02 04:00:00                              0.0
#
#                      event_title_UEFA Women Euro Final  \
# timestamp
# 2022-01-02 00:00:00                                0.0
# 2022-01-02 01:00:00                                0.0
# 2022-01-02 02:00:00                                0.0
# 2022-01-02 03:00:00                                0.0
# 2022-01-02 04:00:00                                0.0
#
#                      event_title_Wimbledon Tennis Championships  \
# timestamp
# 2022-01-02 00:00:00                                         0.0
# 2022-01-02 01:00:00                                         0.0
# 2022-01-02 02:00:00                                         0.0
# 2022-01-02 03:00:00                                         0.0
# 2022-01-02 04:00:00                                         0.0
#
#                      event_title_Winter Wonderland  \
# timestamp
# 2022-01-02 00:00:00                            0.0
# 2022-01-02 01:00:00                            0.0
# 2022-01-02 02:00:00                            0.0
# 2022-01-02 03:00:00                            0.0
# 2022-01-02 04:00:00                            0.0
#
#                     event_title_World Cup 2022 1/4 final event_title_nan
# timestamp
# 2022-01-02 00:00:00                                  0.0             1.0
# 2022-01-02 01:00:00                                  0.0             1.0
# 2022-01-02 02:00:00                                  0.0             1.0
# 2022-01-02 03:00:00                                  0.0             1.0
# 2022-01-02 04:00:00                                  0.0             1.0
#
# [5 rows x 56 columns]

# %% [markdown]
# ## 6. Bool to int encoding

# %%
booltoint = event_encoding.copy()

# %%
booltoint['elisabeth_line'] = np.where(booltoint['elisabeth_line'], '1', '0')

# %%
booltoint['lockdown'] = np.where(booltoint['lockdown'], '1', '0')

# %%
booltoint.head()
# Out:
#                      temperature  rainfall  snowfall  cloudcover  wind_speed  \
# timestamp
# 2022-01-02 00:00:00     0.429952  0.010204       0.0         1.0    0.108333
# 2022-01-02 01:00:00     0.427536  0.010204       0.0         1.0    0.330000
# 2022-01-02 02:00:00     0.427536  0.000000       0.0         1.0    0.310000
# 2022-01-02 03:00:00     0.427536  0.000000       0.0         1.0    0.283333
# 2022-01-02 04:00:00     0.427536  0.000000       0.0         1.0    0.283333
#
#                      wind_direction daytime event_latitude event_longitude  \
# timestamp
# 2022-01-02 00:00:00        0.523677       0              0               0
# 2022-01-02 01:00:00        0.662953       0              0               0
# 2022-01-02 02:00:00        0.668524       0              0               0
# 2022-01-02 03:00:00        0.688022       0              0               0
# 2022-01-02 04:00:00        0.688022       0              0               0
#
#                      London_zone_Central  ...  \
# timestamp                                 ...
# 2022-01-02 00:00:00                  0.0  ...
# 2022-01-02 01:00:00                  0.0  ...
# 2022-01-02 02:00:00                  0.0  ...
# 2022-01-02 03:00:00                  0.0  ...
# 2022-01-02 04:00:00                  0.0  ...
#
#                      event_title_Spring bank holiday  \
# timestamp
# 2022-01-02 00:00:00                              0.0
# 2022-01-02 01:00:00                              0.0
# 2022-01-02 02:00:00                              0.0
# 2022-01-02 03:00:00                              0.0
# 2022-01-02 04:00:00                              0.0
#
#                      event_title_Summer bank holiday  \
# timestamp
# 2022-01-02 00:00:00                              0.0
# 2022-01-02 01:00:00                              0.0
# 2022-01-02 02:00:00                              0.0
# 2022-01-02 03:00:00                              0.0
# 2022-01-02 04:00:00                              0.0
#
#                      event_title_Survival Sunday (Premier League)  \
# timestamp
# 2022-01-02 00:00:00                                           0.0
# 2022-01-02 01:00:00                                           0.0
# 2022-01-02 02:00:00                                           0.0
# 2022-01-02 03:00:00                                           0.0
# 2022-01-02 04:00:00                                           0.0
#
#                      event_title_Taste of London  \
# timestamp
# 2022-01-02 00:00:00                          0.0
# 2022-01-02 01:00:00                          0.0
# 2022-01-02 02:00:00                          0.0
# 2022-01-02 03:00:00                          0.0
# 2022-01-02 04:00:00                          0.0
#
#                      event_title_Trooping the Colour  \
# timestamp
# 2022-01-02 00:00:00                              0.0
# 2022-01-02 01:00:00                              0.0
# 2022-01-02 02:00:00                              0.0
# 2022-01-02 03:00:00                              0.0
# 2022-01-02 04:00:00                              0.0
#
#                      event_title_UEFA Women Euro Final  \
# timestamp
# 2022-01-02 00:00:00                                0.0
# 2022-01-02 01:00:00                                0.0
# 2022-01-02 02:00:00                                0.0
# 2022-01-02 03:00:00                                0.0
# 2022-01-02 04:00:00                                0.0
#
#                     event_title_Wimbledon Tennis Championships  \
# timestamp
# 2022-01-02 00:00:00                                        0.0
# 2022-01-02 01:00:00                                        0.0
# 2022-01-02 02:00:00                                        0.0
# 2022-01-02 03:00:00                                        0.0
# 2022-01-02 04:00:00                                        0.0
#
#                     event_title_Winter Wonderland  \
# timestamp
# 2022-01-02 00:00:00                           0.0
# 2022-01-02 01:00:00                           0.0
# 2022-01-02 02:00:00                           0.0
# 2022-01-02 03:00:00                           0.0
# 2022-01-02 04:00:00                           0.0
#
#                     event_title_World Cup 2022 1/4 final event_title_nan
# timestamp
# 2022-01-02 00:00:00                                  0.0             1.0
# 2022-01-02 01:00:00                                  0.0             1.0
# 2022-01-02 02:00:00                                  0.0             1.0
# 2022-01-02 03:00:00                                  0.0             1.0
# 2022-01-02 04:00:00                                  0.0             1.0
#
# [5 rows x 56 columns]

# %% [markdown]
# ## 7. Strikes and holidays encoding

# %%
strikes_holidays = booltoint.copy()

# %%
strikes_holidays['strike'] = strikes_holidays['strike'].fillna(0)

# %%
strikes_holidays['strike'].value_counts()
# Out:
# strike
# 0             7752
# train          744
# tube           144
# tubetrain       72
# traintrain      48
# Name: count, dtype: int64

# %%
strikes_holidays['strike'] = strikes_holidays['strike'].apply(encoding_strings)

# %%
strikes_holidays['strike'].value_counts()
# Out:
# strike
# 0    7752
# 1    1008
# Name: count, dtype: int64

# %%
strikes_holidays['school_holidays'] = strikes_holidays['school_holidays'].fillna(0)
strikes_holidays['school_holidays'] = strikes_holidays['school_holidays'].apply(encoding_strings)

# %%
strikes_holidays['school_holidays'].value_counts()
# Out:
# school_holidays
# 0    6288
# 1    2472
# Name: count, dtype: int64

# %%
strikes_holidays.head()
# Out:
#                      temperature  rainfall  snowfall  cloudcover  wind_speed  \
# timestamp
# 2022-01-02 00:00:00     0.429952  0.010204       0.0         1.0    0.108333
# 2022-01-02 01:00:00     0.427536  0.010204       0.0         1.0    0.330000
# 2022-01-02 02:00:00     0.427536  0.000000       0.0         1.0    0.310000
# 2022-01-02 03:00:00     0.427536  0.000000       0.0         1.0    0.283333
# 2022-01-02 04:00:00     0.427536  0.000000       0.0         1.0    0.283333
#
#                      wind_direction daytime event_latitude event_longitude  \
# timestamp
# 2022-01-02 00:00:00        0.523677       0              0               0
# 2022-01-02 01:00:00        0.662953       0              0               0
# 2022-01-02 02:00:00        0.668524       0              0               0
# 2022-01-02 03:00:00        0.688022       0              0               0
# 2022-01-02 04:00:00        0.688022       0              0               0
#
#                      London_zone_Central  ...  \
# timestamp                                 ...
# 2022-01-02 00:00:00                  0.0  ...
# 2022-01-02 01:00:00                  0.0  ...
# 2022-01-02 02:00:00                  0.0  ...
# 2022-01-02 03:00:00                  0.0  ...
# 2022-01-02 04:00:00                  0.0  ...
#
#                      event_title_Spring bank holiday  \
# timestamp
# 2022-01-02 00:00:00                              0.0
# 2022-01-02 01:00:00                              0.0
# 2022-01-02 02:00:00                              0.0
# 2022-01-02 03:00:00                              0.0
# 2022-01-02 04:00:00                              0.0
#
#                      event_title_Summer bank holiday  \
# timestamp
# 2022-01-02 00:00:00                              0.0
# 2022-01-02 01:00:00                              0.0
# 2022-01-02 02:00:00                              0.0
# 2022-01-02 03:00:00                              0.0
# 2022-01-02 04:00:00                              0.0
#
#                      event_title_Survival Sunday (Premier League)  \
# timestamp
# 2022-01-02 00:00:00                                           0.0
# 2022-01-02 01:00:00                                           0.0
# 2022-01-02 02:00:00                                           0.0
# 2022-01-02 03:00:00                                           0.0
# 2022-01-02 04:00:00                                           0.0
#
#                      event_title_Taste of London  \
# timestamp
# 2022-01-02 00:00:00                          0.0
# 2022-01-02 01:00:00                          0.0
# 2022-01-02 02:00:00                          0.0
# 2022-01-02 03:00:00                          0.0
# 2022-01-02 04:00:00                          0.0
#
#                      event_title_Trooping the Colour  \
# timestamp
# 2022-01-02 00:00:00                              0.0
# 2022-01-02 01:00:00                              0.0
# 2022-01-02 02:00:00                              0.0
# 2022-01-02 03:00:00                              0.0
# 2022-01-02 04:00:00                              0.0
#
#                      event_title_UEFA Women Euro Final  \
# timestamp
# 2022-01-02 00:00:00                                0.0
# 2022-01-02 01:00:00                                0.0
# 2022-01-02 02:00:00                                0.0
# 2022-01-02 03:00:00                                0.0
# 2022-01-02 04:00:00                                0.0
#
#                     event_title_Wimbledon Tennis Championships  \
# timestamp
# 2022-01-02 00:00:00                                        0.0
# 2022-01-02 01:00:00                                        0.0
# 2022-01-02 02:00:00                                        0.0
# 2022-01-02 03:00:00                                        0.0
# 2022-01-02 04:00:00                                        0.0
#
#                     event_title_Winter Wonderland  \
# timestamp
# 2022-01-02 00:00:00                           0.0
# 2022-01-02 01:00:00                           0.0
# 2022-01-02 02:00:00                           0.0
# 2022-01-02 03:00:00                           0.0
# 2022-01-02 04:00:00                           0.0
#
#                      event_title_World Cup 2022 1/4 final  event_title_nan
# timestamp
# 2022-01-02 00:00:00                                   0.0              1.0
# 2022-01-02 01:00:00                                   0.0              1.0
# 2022-01-02 02:00:00                                   0.0              1.0
# 2022-01-02 03:00:00                                   0.0              1.0
# 2022-01-02 04:00:00                                   0.0              1.0
#
# [5 rows x 56 columns]

# %%
strikes_holidays.shape
# Out:
# (8760, 56)

# %%
strikes_holidays.columns
# Out:
# Index(['temperature', 'rainfall', 'snowfall', 'cloudcover', 'wind_speed',
#        'wind_direction', 'daytime', 'event_latitude', 'event_longitude',
#        'London_zone_Central', 'London_zone_South_East', 'London_zone_East',
#        'London_zone_London_all', 'London_zone_North', 'London_zone_South_West',
#        'London_zone_West', 'elisabeth_line', 'lockdown', 'school_holidays',
#        'strike', 'year', 'month', 'day', 'hour', 'minute', 'second', 'weekday',
#        'event_title_Bank Holiday for the State Funeral of Queen Elizabeth II',
#        'event_title_Boxing Day', 'event_title_Champions League Final',
#        'event_title_Chelsea Flower Show', 'event_title_Christmas Day',
#        'event_title_Diwali on Trafalgar Square',
#        'event_title_Early May bank holiday', 'event_title_Easter Monday',
#        'event_title_Frieze Art Fair', 'event_title_Good Friday',
#        'event_title_Guy Fawkes Night (Bonfire Night)',
#        'event_title_Halloween in London', 'event_title_London Film Festival',
#        'event_title_London Marathon', 'event_title_New Year's Eve Fireworks',
#        'event_title_New Year’s Day', 'event_title_Notting Hill Carnival',
#        'event_title_Platinum Jubilee bank holiday',
#        'event_title_Pride in London', 'event_title_Spring bank holiday',
#        'event_title_Summer bank holiday',
#        'event_title_Survival Sunday (Premier League)',
#        'event_title_Taste of London', 'event_title_Trooping the Colour',
#        'event_title_UEFA Women Euro Final',
#        'event_title_Wimbledon Tennis Championships',
#        'event_title_Winter Wonderland', 'event_title_World Cup 2022 1/4 final',
#        'event_title_nan'],
#       dtype='object')

# %%
strikes_holidays.describe()
# Out:
#        temperature     rainfall     snowfall   cloudcover   wind_speed  \
# count  8760.000000  8760.000000  8760.000000  8760.000000  8760.000000
# mean      0.433749     0.008020     0.000875     0.569807     0.240084
# std       0.184441     0.032277     0.025914     0.402340     0.134634
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.311594     0.000000     0.000000     0.220000     0.146667
# 50%       0.417874     0.000000     0.000000     0.560000     0.211667
# 75%       0.538647     0.000000     0.000000     0.940000     0.306667
# max       1.318841     1.000000     1.000000     2.000000     1.133333
#
#        wind_direction  London_zone_Central  London_zone_South_East  \
# count     8760.000000          8760.000000             8760.000000
# mean         0.545353             0.216438                0.052055
# std          0.306444             0.462009                0.222150
# min          0.000000             0.000000                0.000000
# 25%          0.328691             0.000000                0.000000
# 50%          0.565460             0.000000                0.000000
# 75%          0.710306             0.000000                0.000000
# max          2.000000             2.000000                1.000000
#
#        London_zone_East  London_zone_London_all  ...  \
# count       8760.000000             8760.000000  ...
# mean           0.079452                0.104110  ...
# std            0.270458                0.322865  ...
# min            0.000000                0.000000  ...
# 25%            0.000000                0.000000  ...
# 50%            0.000000                0.000000  ...
# 75%            0.000000                0.000000  ...
# max            1.000000                2.000000  ...
#
#        event_title_Spring bank holiday  event_title_Summer bank holiday  \
# count                      8760.000000                      8760.000000
# mean                          0.002740                         0.002740
# std                           0.052274                         0.052274
# min                           0.000000                         0.000000
# 25%                           0.000000                         0.000000
# 50%                           0.000000                         0.000000
# 75%                           0.000000                         0.000000
# max                           1.000000                         1.000000
#
#        event_title_Survival Sunday (Premier League)  \
# count                                   8760.000000
# mean                                       0.002740
# std                                        0.052274
# min                                        0.000000
# 25%                                        0.000000
# 50%                                        0.000000
# 75%                                        0.000000
# max                                        1.000000
#
#        event_title_Taste of London  event_title_Trooping the Colour  \
# count                  8760.000000                      8760.000000
# mean                      0.013699                         0.002740
# std                       0.116243                         0.052274
# min                       0.000000                         0.000000
# 25%                       0.000000                         0.000000
# 50%                       0.000000                         0.000000
# 75%                       0.000000                         0.000000
# max                       1.000000                         1.000000
#
#        event_title_UEFA Women Euro Final  \
# count                        8760.000000
# mean                            0.002740
# std                             0.052274
# min                             0.000000
# 25%                             0.000000
# 50%                             0.000000
# 75%                             0.000000
# max                             1.000000
#
#        event_title_Wimbledon Tennis Championships  \
# count                                 8760.000000
# mean                                     0.038356
# std                                      0.192066
# min                                      0.000000
# 25%                                      0.000000
# 50%                                      0.000000
# 75%                                      0.000000
# max                                      1.000000
#
#        event_title_Winter Wonderland  event_title_World Cup 2022 1/4 final  \
# count                    8760.000000                           8760.000000
# mean                        0.126027                              0.002740
# std                         0.340055                              0.052274
# min                         0.000000                              0.000000
# 25%                         0.000000                              0.000000
# 50%                         0.000000                              0.000000
# 75%                         0.000000                              0.000000
# max                         2.000000                              1.000000
#
#        event_title_nan
# count      8760.000000
# mean          0.745205
# std           0.448170
# min           0.000000
# 25%           0.000000
# 50%           1.000000
# 75%           1.000000
# max           2.000000
#
# [8 rows x 45 columns]

# %%
strikes_holidays.drop(columns="event_latitude", inplace=True)

# %%
strikes_holidays.drop(columns="event_longitude", inplace=True)

# %%
strikes_holidays.shape
# Out:
# (8760, 54)

# %%
strikes_holidays.to_csv('../../../raw_data/final_features_preproc_12m.csv')
