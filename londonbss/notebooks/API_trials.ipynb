# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
import glob
from londonbss.params import *
from londonbss.ml_logic.registry import load_model
import matplotlib.pyplot as plt

# %%
station_name = 'wenlock_road___hoxton'

# %%
model = load_model(stage='production', n_station=station_name)
# Out:
# Load latest model from GCS...
# ✅ Latest model downloaded from cloud storage

# %%
pred_es = model.predict(n=3984)

# %%
plt.figure(figsize=(20, 5))
pred_es[-168:].plot(linewidth=1, label="pred")
# Out:
# <Axes: xlabel='startdate'>

# %%
pred_es.to_json()
# Out:
# '{"columns":["wenlock_road___hoxton"],"index":["2022-12-31T00:00:00.000","2022-12-31T01:00:00.000","2022-12-31T02:00:00.000","2022-12-31T03:00:00.000","2022-12-31T04:00:00.000","2022-12-31T05:00:00.000","2022-12-31T06:00:00.000","2022-12-31T07:00:00.000","2022-12-31T08:00:00.000","2022-12-31T09:00:00.000","2022-12-31T10:00:00.000","2022-12-31T11:00:00.000","2022-12-31T12:00:00.000","2022-12-31T13:00:00.000","2022-12-31T14:00:00.000","2022-12-31T15:00:00.000","2022-12-31T16:00:00.000","2022-12-31T17:00:00.000","2022-12-31T18:00:00.000","2022-12-31T19:00:00.000","2022-12-31T20:00:00.000","2022-12-31T21:00:00.000","2022-12-31T22:00:00.000","2022-12-31T23:00:00.000","2023-01-01T00:00:00.000","2023-01-01T01:00:00.000","2023-01-01T02:00:00.000","2023-01-01T03:00:00.000","2023-01-01T04:00:00.000","2023-01-01T05:00:00.000","2023-01-01T06:00:00.000","2023-01-01T07:00:00.000","2023-01-01T08:00:00.000","2023-01-01T09:00:00.000","2023-01-01T10:00:00.000","2023-01-01T11:00:00.000","2023-01-01T12:
# ...

# %%
from darts.models import ExponentialSmoothing

# %%
most_recent_model_path_on_disk = '/home/sebasmar/code/elsebasmar/london-bss/training_outputs/models/20230920-102451-wenlock_road___hoxton.pkl'

# %%
latest_model = ExponentialSmoothing.load(most_recent_model_path_on_disk)
