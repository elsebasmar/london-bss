# %%
import pandas as pd
query = '''
  SELECT *
  FROM `wagon-bootcamp-396316.londonbss.processed_full_data_2`
'''
df = pd.read_gbq(query, project_id="wagon-bootcamp-396316")
df
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 6
#       1 import pandas as pd
#       2 query = '''
#       3   SELECT *
#       4   FROM `wagon-bootcamp-396316.londonbss.processed_full_data_2`
#       5 '''
# ----> 6 df = pd.read_gbq(query, project_id="wagon-bootcamp-396316")
#       7 df
#
# File ~/.pyenv/versions/3.10.6/envs/london-bss/lib/python3.10/site-packages/pandas/io/gbq.py:186, in read_gbq(query, project_id, index_col, col_order, reauth, auth_local_webserver, dialect, location, configuration, credentials, use_bqstorage_api, max_results, progress_bar_type)
#     183 kwargs["progress_bar_type"] = progress_bar_type
#     184 # END: new kwargs
# --> 186 return pandas_gbq.read_gbq(
#     187     query,
#     188     project_id=project_id,
#     189     index_col=index_col,
#     190     col_order=col_order,
#     191     reauth=reauth,
# ...
