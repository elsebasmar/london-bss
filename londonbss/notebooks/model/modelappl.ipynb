# %%
import os
import sys

# %%
os.path.realpath(sys.argv[1])
# Out:
# '/home/sebasmar/code/elsebasmar/london-bss/londonbss/notebooks/model/--ip=127.0.0.1'

# %%
os.getcwd()
# Out:
# '/home/sebasmar/code/elsebasmar/london-bss/londonbss/notebooks/model'
